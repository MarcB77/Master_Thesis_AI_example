# %% [markdown]
# Download via terminal, so locally on your machine.
# python -m spacy download nl_core_news_lg
# python -m spacy download en_core_web_lg

# %%
# %run ../Functions/Functions_Finalized.ipynb

# %%
df_FreeOfAlcohol = pd.read_csv('../dataset/FreeOfAlcohol_noempty.csv', sep=';')

# %%
NLP_nd = Natural_Language_Processing_nd(df_FreeOfAlcohol, input_features=["regulatedProdName","functionalName","labelDescription","TradeItemDescr","ingredient_informatie"], filename="NLP_processed_noEmpty")
df_preprocessed, tokenizer = NLP_nd.NLP_Loop(overwrite_tokenizer=False, overwrite_NLP_table=True)
# Out:
# Feature, empty fieldsregulatedProdName  77
# Feature, empty fieldsfunctionalName  0
# Feature, empty fieldslabelDescription  81
# Feature, empty fieldsTradeItemDescr  0
# Feature, empty fieldsingredient_informatie  102
# Punctuation that will be removed:  !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# Most common words:
#  [('bier', 466), ('water', 409), ('ingrediënten', 370), ('zout', 256), ('suiker', 231), ('gerstemout', 218), ('00', 196), ('alcoholvrij', 195), ('hop', 189), ('ah', 155)]
# Lemmmatization, takes a while..
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/marcblomvliet/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Lemmatization done!
# Max length of dutch:  210

# %%
display(df_preprocessed.head())
# Out:
#           gtin  ndFreeOfAlcohol          gln regulatedProdName  \
# 0  4;06057E+12             True  4;06057E+12              Wine
# 1  4;06057E+12             True  4;06057E+12              Wine
# 2  4;06057E+12             True  4;06057E+12              Wine
# 3  4;06057E+12             True  4;06057E+12              Wine
# 4     96199510             True  5;03886E+12   Hot ginger shot
#
#             functionalName                                   labelDescription  \
# 0       Getränk / Beverage                Free Feather alcoholfree Chardonnay
# 1       Getränk / Beverage                    Free Feather alcoholfree Merlot
# 2  Alkoholfreier Weisswein  Free Feather - Free feather wit Alcoholvrij kv...
# 3    Alkoholfreier Rotwein  Free Feather - Free feather rood Alcoholvrij k...
# 4          Hot ginger shot
#
#                                       TradeItemDescr  \
# 0                    Feather Alcoholfree white wine
# 1                      Feather Alcoholfree red wine
# ...
