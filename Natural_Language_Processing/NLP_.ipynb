# %% [markdown]
# Download via terminal, so locally on your machine.
# python -m spacy download nl_core_news_lg
# python -m spacy download en_core_web_lg

# %%
# %run ../Functions/Functions_Finalized.ipynb

# %%
df_FreeOfAlcohol = pd.read_csv('../dataset/ndFreeOfAlcohol_example_dataset.csv', sep=';')

# %%
NLP_nd = Natural_Language_Processing_nd(df_FreeOfAlcohol, input_features=["regulatedProdName","functionalName","labelDescription","TradeItemDescr","ingredient_informatie"], filename="NLP_processed_")
df_preprocessed, tokenizer = NLP_nd.NLP_Loop(overwrite_tokenizer=False, overwrite_NLP_table=True)
# Out:
# Feature, empty fieldsregulatedProdName  76
# Feature, empty fieldsfunctionalName  15
# Feature, empty fieldslabelDescription  111
# Feature, empty fieldsTradeItemDescr  0
# Feature, empty fieldsingredient_informatie  90
# Punctuation that will be removed:  !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# Most common words:
#  [('ingrediënten', 841), ('water', 617), ('bier', 587), ('zout', 462), ('suiker', 401), ('gerstemout', 372), ('hop', 301), ('melk', 288), ('blik', 225), ('aroma', 201)]
# Lemmmatization, takes a while..
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/marcblomvliet/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Lemmatization done!
# Max length of dutch:  237

# %%
display(df_preprocessed.head())
# Out:
#           gtin          gln  ndFreeOfAlcohol  \
# 0   8;7227E+12  5;41003E+12            False
# 1   7;6222E+12  5;41008E+12            False
# 2   7;6222E+12  5;41008E+12            False
# 3  5;01068E+12   5;4101E+12            False
# 4  5;01068E+12   5;4101E+12            False
#
#                                    regulatedProdName         functionalName  \
# 0                               Geconcentreerde soep                   Soep
# 1  Zachte chocoladecake met chocoladevulling (15 ...              SOFT CAKE
# 2  Zachte chocoladecake met chocoladevulling (15 ...              SOFT CAKE
# 3                              Alcoholische Mixdrank  Alcoholische Mixdrank
# 4                              Alcoholische Mixdrank  Alcoholische Mixdrank
#
#                                     labelDescription  \
# 0                          Knorr Kreeftensoep 515 ml
# 1  LU Moelleux Trio Zachte Cake Vanille & Chocola...
# 2  LU Moelleux Trio Zachte Cake Vanille & Chocola...
# 3
# 4
#
#                                       TradeItemDescr  \
# 0                      DB 56cu Knorr Cans Kreeft DLL
# 1                              LU SOFT CAKE SUPERMIX
# 2                              LU SOFT CAKE SUPERMIX
# 3  BACARDI Alcoholische Mix Drank Razz & Up 250 m...
# 4  BACARDI Alcoholische Mixdrank Carta Blanca and...
#
#                                ingredient_informatie  \
# 0  Ingrediënten: Water, TARWEBLOEM, tomatenpuree^...
# 1  Ingrediënten: TARWEBLOEM 24%, suiker, palmolie...
# 2  Ingrediënten: TARWEBLOEM 24%, suiker, palmolie...
# 3
# 4                       Ingredienten: Bevat cafeïne.
#
#                                    all_text_features  \
# 0  Geconcentreerde soep Soep Knorr Kreeftensoep 5...
# 1  Zachte chocoladecake met chocoladevulling (15 ...
# 2  Zachte chocoladecake met chocoladevulling (15 ...
# 3  Alcoholische Mixdrank Alcoholische Mixdrank  B...
# 4  Alcoholische Mixdrank Alcoholische Mixdrank  B...
#
#                                            lowercase  \
# 0  geconcentreerde soep soep knorr kreeftensoep 5...
# 1  zachte chocoladecake met chocoladevulling (15 ...
# 2  zachte chocoladecake met chocoladevulling (15 ...
# 3  alcoholische mixdrank alcoholische mixdrank  b...
# 4  alcoholische mixdrank alcoholische mixdrank  b...
#
#                                       no_punctuation  \
# 0  geconcentreerde soep soep knorr kreeftensoep 5...
# 1  zachte chocoladecake met chocoladevulling 15  ...
# 2  zachte chocoladecake met chocoladevulling 15  ...
# 3  alcoholische mixdrank alcoholische mixdrank  b...
# 4  alcoholische mixdrank alcoholische mixdrank  b...
#
#                                         NO_stopwords  \
# 0  geconcentreerde soep soep knorr kreeftensoep 5...
# 1  zachte chocoladecake chocoladevulling 15 bedek...
# 2  zachte chocoladecake chocoladevulling 15 bedek...
# 3  alcoholische mixdrank alcoholische mixdrank ba...
# 4  alcoholische mixdrank alcoholische mixdrank ba...
#
#                                     lemmatized_DUTCH  \
# 0  concentreren soep soep knorr kreeftensoep 515 ...
# 1  zacht chocoladecake chocoladevulling 15 bedekk...
# 2  zacht chocoladecake chocoladevulling 15 bedekk...
# 3  alcoholisch mixdrank alcoholisch mixdrank baca...
# 4  alcoholisch mixdrank alcoholisch mixdrank baca...
#
#                                      tokenized_DUTCH  length_tokenized  \
# 0  [concentreren, soep, soep, knorr, kreeftensoep...                45
# 1  [zacht, chocoladecake, chocoladevulling, 15, b...                78
# 2  [zacht, chocoladecake, chocoladevulling, 15, b...                78
# 3  [alcoholisch, mixdrank, alcoholisch, mixdrank,...                13
# 4  [alcoholisch, mixdrank, alcoholisch, mixdrank,...                17
#
#                                          padded_seq_
# 0  [107, 51, 51, 48, 1965, 681, 53, 1966, 1967, 4...
# 1  [358, 966, 616, 128, 753, 967, 968, 617, 230, ...
# 2  [358, 966, 616, 128, 753, 967, 968, 617, 230, ...
# 3  [220, 236, 220, 236, 340, 220, 23, 81, 1184, 1...
# 4  [220, 236, 220, 236, 340, 220, 236, 540, 541, ...
