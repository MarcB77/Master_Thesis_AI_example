# %% [markdown]
# Download via terminal, so locally on your machine.
# python -m spacy download nl_core_news_lg
# python -m spacy download en_core_web_lg

# %%
# %run ../Functions/Functions_Finalized.ipynb

# %%
df_FreeOfAlcohol = pd.read_csv('../dataset/ndFreeOfAlcohol_example_dataset.csv', sep=';')

# %%
NLP_nd = Natural_Language_Processing_nd(df_FreeOfAlcohol, input_features=["regulatedProdName","functionalName","labelDescription","TradeItemDescr","ingredient_informatie"], filename="NLP_processed_")
df_preprocessed, tokenizer = NLP_nd.NLP_Loop(overwrite_tokenizer=False, overwrite_NLP_table=True)
# Out:
# Feature, empty fieldsregulatedProdName  71
# Feature, empty fieldsfunctionalName  11
# Feature, empty fieldslabelDescription  108
# Feature, empty fieldsTradeItemDescr  0
# Feature, empty fieldsingredient_informatie  104
# Punctuation that will be removed:  !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# Most common words:
#  [('ingrediënten', 813), ('water', 595), ('bier', 539), ('zout', 462), ('suiker', 389), ('gerstemout', 345), ('melk', 288), ('hop', 265), ('blik', 211), ('aroma', 201)]
# Lemmmatization, takes a while..
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/marcblomvliet/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Lemmatization done!
# Max length of dutch:  237

# %%
display(df_preprocessed.head())
# Out:
#           gtin          gln  ndFreeOfAlcohol  \
# 0  5;05399E+12  38000000072             True
# 1  5;05399E+12  38000000072             True
# 2  5;05399E+12  38000000072             True
# 3  5;05399E+12  38000000072             True
# 4  5;05399E+12  38000000072             True
#
#                            regulatedProdName functionalName labelDescription  \
# 0                             HARTIGE SNACK.  Hartige snack
# 1  HARTIGE SNACK MET ZURE ROOM- & UIENSMAAK.  Hartige snack
# 2  HARTIGE SNACK MET ZURE ROOM- & UIENSMAAK.  Hartige snack
# 3       HARTIGE SNACK MET KAAS- & UIENSMAAK.  Hartige snack
# 4   HARTIGE SNACK MET PITTIG GEKRUIDE SMAAK.  Hartige snack
#
#                     TradeItemDescr  \
# 0            Pringles Original 40g
# 1  Pringles Sour Cream & Onion 40g
# 2    Pringles Sour Cream&Onion 70g
# 3   Pringles CHEESE&ONION CHO 165g
# 4    Pringles Hot & Spicy H&S 165g
#
#                                ingredient_informatie  \
# ...
